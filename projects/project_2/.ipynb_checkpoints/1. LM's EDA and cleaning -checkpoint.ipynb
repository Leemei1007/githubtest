# %%
# import the relevant libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno 

# %matplotlib inline

# %% [markdown]
# ### Data cleaning - train set

# %%
data = pd.read_csv('./datasets/train.csv')

#to be able to see all columns
pd.set_option('display.max_columns', None)

# %%
data.head(10)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   109  533352170           60        RL           NaN     13517   Pave
# 1   544  531379050           60        RL          43.0     11492   Pave
# 2   153  535304180           20        RL          68.0      7922   Pave
# 3   318  916386060           60        RL          73.0      9802   Pave
# 4   255  906425045           50        RL          82.0     14235   Pave
# 5   138  535126040           20        RL         137.0     16492   Pave
# 6  2827  908186070          180        RM          35.0      3675   Pave
# 7   145  535154050           20        RL           NaN     12160   Pave
# 8  1942  535353130           20        RL           NaN     15783   Pave
# 9  1956  535426130           60        RL          70.0     11606   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %%
# data_null = pd.DataFrame(df[num_col].isnull().sum(), columns=['null_count'])

# %%
# null_sum = data.isnull().sum()

# %%
data_null_or_not = pd.DataFrame(data.isnull().sum(), columns=['null_count'])

# %%
#adding a percentage column to ascertain the proportion of null

data_null_or_not['proportion_null'] = data_null_or_not['null_count'] / 2051 * 100

# %%
#filter out non-nulls

data_null = data_null_or_not[data_null_or_not['null_count'] > 0]

# %%
data_null.sort_values(by=['proportion_null'], ascending = False)

# for columns with proportion null of 5.56% and less, I shall assign a zero / 'None' value since the number of nulls are insignificant compared to the whole dataset
# Out:
#                 null_count  proportion_null
# Pool QC               2042        99.561190
# Misc Feature          1986        96.830814
# Alley                 1911        93.174061
# Fence                 1651        80.497318
# Fireplace Qu          1000        48.756704
# Lot Frontage           330        16.089712
# Garage Yr Blt          114         5.558264
# Garage Cond            114         5.558264
# Garage Qual            114         5.558264
# Garage Finish          114         5.558264
# Garage Type            113         5.509508
# Bsmt Exposure           58         2.827889
# BsmtFin Type 2          56         2.730375
# Bsmt Cond               55         2.681619
# Bsmt Qual               55         2.681619
# BsmtFin Type 1          55         2.681619
# Mas Vnr Area            22         1.072647
# Mas Vnr Type            22         1.072647
# Bsmt Half Bath           2         0.097513
# Bsmt Full Bath           2         0.097513
# ...

# %%
#these are the columns with insignificant number of NaN, i.e. 5.6% and below.
#Since the number of Nan is deemed insignificant, i shall assign a zero to those float datatype and 'None' to those object type

features_insignificant_null = ['BsmtFin SF 1', 
            'Garage Area', 
            'Garage Cars', 
            'BsmtFin SF 2', 
            'Bsmt Unf SF',
            'Total Bsmt SF',                   
            'Bsmt Full Bath', 
            'Bsmt Half Bath',
            'Mas Vnr Type',
           'Mas Vnr Area',
           'BsmtFin Type 1',
           'Bsmt Qual',
           'Bsmt Cond',
           'BsmtFin Type 2',
           'Bsmt Exposure',
           'Garage Type',
           'Garage Finish',
           'Garage Qual',
           'Garage Cond',
           'Garage Yr Blt']

# %%
data[features_insignificant_null].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   BsmtFin SF 1    2050 non-null   float64
#  1   Garage Area     2050 non-null   float64
#  2   Garage Cars     2050 non-null   float64
#  3   BsmtFin SF 2    2050 non-null   float64
#  4   Bsmt Unf SF     2050 non-null   float64
#  5   Total Bsmt SF   2050 non-null   float64
#  6   Bsmt Full Bath  2049 non-null   float64
#  7   Bsmt Half Bath  2049 non-null   float64
#  8   Mas Vnr Type    2029 non-null   object
#  9   Mas Vnr Area    2029 non-null   float64
#  10  BsmtFin Type 1  1996 non-null   object
#  11  Bsmt Qual       1996 non-null   object
#  12  Bsmt Cond       1996 non-null   object
#  13  BsmtFin Type 2  1995 non-null   object
#  14  Bsmt Exposure   1993 non-null   object
#  15  Garage Type     1938 non-null   object
#  16  Garage Finish   1937 non-null   object
# ...

# %%
# for features with floats, i'll assign a zero

# %%
data['BsmtFin SF 1'].fillna(0, inplace = True)

# %%
data['Garage Area'].fillna(0, inplace = True)

# %%
data['Garage Cars'].fillna(0, inplace = True)

# %%
data['BsmtFin SF 2'].fillna(0, inplace = True)

# %%
data['Bsmt Unf SF'].fillna(0, inplace = True)

# %%
data['Total Bsmt SF'].fillna(0, inplace = True)

# %%
data['Bsmt Full Bath'].fillna(0, inplace = True)

# %%
data['Bsmt Half Bath'].fillna(0, inplace = True)

# %%
data['Mas Vnr Area'].fillna(0, inplace = True)

# %%
data['Garage Yr Blt'].fillna(0, inplace = True)

# %%
# for features with objects, i'll assign a 'None'

# %%
data['Mas Vnr Type'].fillna('None', inplace = True)

# %%
data['BsmtFin Type 1'].fillna('None', inplace = True)

# %%
data['Bsmt Qual'].fillna('None', inplace = True)

# %%
data['Bsmt Cond'].fillna('None', inplace = True)

# %%
data['BsmtFin Type 2'].fillna('None', inplace = True)

# %%
data['Bsmt Exposure'].fillna('None', inplace = True)

# %%
data['Garage Type'].fillna('None', inplace = True)

# %%
data['Garage Finish'].fillna('None', inplace = True)

# %%
data['Garage Qual'].fillna('None', inplace = True)

# %%
data['Garage Cond'].fillna('None', inplace = True)

# %%
#these are the columns with SIGNIFICANT number of NaN, and these seem to be important features so we have to decide how to treat this:

features_significant_null = ['Pool QC',
                             'Misc Feature',
                             'Alley',
                             'Fence',
                             'Fireplace Qu',
                             'Lot Frontage']

data[features_significant_null].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pool QC       9 non-null      object
#  1   Misc Feature  65 non-null     object
#  2   Alley         140 non-null    object
#  3   Fence         400 non-null    object
#  4   Fireplace Qu  1051 non-null   object
#  5   Lot Frontage  1721 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 96.3+ KB

# %%
data['age'] = (2021 - data['Year Built']) 

# ('Sat 2018 scores- average, {}'.format(average_scores_18))

# %%
lot_frontage = data['Lot Frontage']
lot_frontage_mean = round(lot_frontage.mean())
lot_frontage_mode = round(lot_frontage.mode())
lot_frontage_median = round(lot_frontage.median())

# %%
plt.title('Lot frontage: average = {}'.format(lot_frontage_mean))
plt.hist(lot_frontage)
# Out:
# (array([315., 918., 417.,  57.,   9.,   2.,   1.,   0.,   0.,   2.]),
#  array([ 21. ,  50.2,  79.4, 108.6, 137.8, 167. , 196.2, 225.4, 254.6,
#         283.8, 313. ]),
#  <a list of 10 Patch objects>)

# %%
print(lot_frontage_median)
print(lot_frontage_mode)
# Out:
# 68
# 0    60.0
# dtype: float64

# %%
# I think it doesnt make sense to assume zero lot frontage. Looking at the mean and median lot frontage data of about 68 and 69 and mode is at 60, I shall input NAN lot frontage with the mean, i.e. 69

# %%
data['Lot Frontage'].fillna(lot_frontage_mean, inplace = True)

# %%
#anymore Nan checked

data['Lot Frontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# about Fireplace quality, the categories comprise of excellent, good, average...
# based on what I read, to repair a fireplace is not costly, it can be as low as $160 and as high as $5,000
# given the relatively low repair cost (which is an indication that fireplace condition is not an important factor), I'm going to deduce that fireplace quality is not an important feature
# given the high number of missing variables, fireplace qu will be dropped
#
# source - https://www.angi.com/articles/how-much-does-repairing-fireplace-or-woodstove-cost.htm#:~:text=Repairing%20a%20fireplace%20costs%20an,%24100%20to%20%24300%20on%20average.

# %%
data['Alley'].unique()
# Out:
# array([nan, 'Pave', 'Grvl'], dtype=object)

# %%
#the house will either have an alley or no alley... type of alley wont be crucial.. hence, i'll just assign 'pave' and 'grvl' as 1 and Nan as 0

data['Alley'].fillna(0, inplace = True)

data['Alley'] = data['Alley'].replace('Pave', 1)
data['Alley'] = data['Alley'].replace('Grvl', 1)

# %%
data['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %%
#not all houses come with fence
#i shall assign 'None' for those without value

data['Fence'].fillna('None', inplace = True)

data['Fence'].unique()
# Out:
# array(['None', 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %%
#as for pool

# %%
data['Pool Area'].isnull().sum()
# Out:
# 0

# %%
msno.matrix(data[features_significant_null])

# %%
msno.heatmap(data[features_significant_null])

# %%
msno.heatmap(data)
