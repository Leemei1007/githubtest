# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
#
# **Scenario:
#  A client which is a Singapore-based company, is in the business of private tutoring (both online and in-class tutor). The client has been providing SATS private tutoring to international school students in Singapore who adopt the USA education syllabus and the client's method of teaching and contents have been well received and regarded. In view of such resounding success, the client now wishes to expand its online tutoring for SATS in the USA. As the client is relatively unknown outside of Singapore, for a start, it has to invest in advertising its business. As advertising throughout the whole USA can be costly, the client is asking for advice which USA state should it target its advertising as part of its pilot programme? In addition, as part of its community service publicity, it has allocated some budget/financial aid to award scholarships to deserving students.**
#
# **Problem statement :**
#
# **1. To analyse which state is the most promising for the client to promote its services**
#
# **2. Targeted states: states with the highest and lowest participation rate**

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **Additional information**
#
# **Our client is confident that SAT is here to stay. Examination, although it has its limitations, also serves as an indicator of a student's behaviour/attitude, i.e. an indication of the student's discipline, resilience and character, and even though some colleges/universities have resorted to omit SAT requirement, it will still be beneficial for the student to undergo SAT to be able to differentiate him/herself among the crowd, be it for college application or job application someday.**

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Selected dataset**
#
# * sat_2017.csv: 2017 SAT Scores by State
# * sat_2018.csv: 2018 SAT Scores by State
# * sat_2019.csv: 2019 SAT Scores by State
# * (Additional imported data) USA_income.csv: Yearly USA median income by state (Source - https://www.census.gov/data/tables/time-series/demo/income-poverty/historical-income-households.html)
#
# **Additional note - Year 2020 data was not chosen for analysis as the year 2020 was an unprecedented year (i.e. global disaster caused by Covid-19 pandemic). As each USA state was governed differently, for eg. not all states imposed lock downs and each test center made individual decisions about whether to administer the SAT, the year 2020 data may be skewed**
#
# Source(https://pages.collegeboard.org/sat-covid-19-updates)

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **Findings from outside research:**
#
# Not all USA states made SAT compulsory. The following are the states in the USA whereby SAT is compulsory / encouraged (via free administration):
#
#  * Colorado - As of the 2016-17 school year, all Colorado juniors in public schools will take the SAT.
#  * Connecticut - As of the 2015-16 school year, all Connecticut juniors will take the SAT.
#  * Delaware - In 2016, the SAT replaced Delaware's Smarter Assessment state test for 11th graders.
#  * Idaho- Each year, Idaho offers a FREE administration of the SAT to high school juniors.
#  * Illinois - Beginning with the 2016-17 school year, all Illinois juniors must take the SAT.
#  * Michigan - Michigan administered the SAT to juniors statewide for the first time in the 2015-16 school year. Previously, students were given the ACT.
#  * Rhode Island - Since the 2017-18 school year, all Rhode Island 11th graders must take the SAT.
#  * South Carolina - Students in South Carolina must take either the SAT or ACT. Which test you take will be determined by your school district.
#  * Tenessee - Students must take either the SAT or ACT.
#  * West Virginia - All juniors must take the SAT unless taking the West Virginia Alternative Summer Assessment.
#  * Maine - Each year, Maine offers a FREE administration of the SAT to high school juniors.
#  * New Hampshire - As of spring 2016, all New Hampshire juniors must take the SAT.
#
# Source: https://blog.prepscholar.com/which-states-require-the-sat

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def mean(y):
    
    total = 0
    count = 0
    
    for numbers in y:
        total += numbers
        count += 1
        average = total / count
    return average
    
#to test

test = 2,2,8,9,4,7,6,6

mean(test)

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def std_dev(y):
    
    Sum_x_minus_mean_sq = 0
    count_x_minus_mean_sq = 0

    for g in test:
        x_minus_mean = g - mean(y)
        x_minus_mean_sq = x_minus_mean**2
    
        Sum_x_minus_mean_sq += x_minus_mean_sq
        count_x_minus_mean_sq += 1
    
        variance = Sum_x_minus_mean_sq / count_x_minus_mean_sq
    
        std_dev = variance ** 0.5
    
    return std_dev

#to test

std_dev(test)

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def str_convert(x):

    if isinstance(x,str) == True:    
        x = x.replace('%','')
        x = x.replace('—','0')
        
    x = float(x)/100
        
    return x

sample = '20%'

str_convert(sample)

# %%
#to convert string to float without dividing by 100

def obj_convert(x):

    if isinstance(x,str) == True:    
        x = x.replace(',','')
        x = float(x)
        
    return x

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:

import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# **1) Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.**

# %% [markdown]
# **SATS**

# %%
sat_2019 = pd.read_csv('sat_2019.csv')
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_2018 = pd.read_csv('sat_2018.csv')
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2017 = pd.read_csv('sat_2017.csv')
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# **2) Check for missing values.**

# %% [markdown]
# **SATS**

# %%
sat_2019.info()

#checked for nulls -> no nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
sat_2018.info()

#checked for nulls -> no nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2017.info()

#checked for nulls -> no nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# **3) Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).**

# %% [markdown]
# **SATS**

# %%
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# **4) Fix any errors you identified in steps 2-3.**

# %% [markdown]
# **SATS**

# %%
# remove district of columbia, puerto rico and virginia island - these are not USA states

sat_2019.drop([8, 39, 47], inplace = True)

# %%
#reset the index after removing non-USA states

sat_2019.reset_index(inplace = True)

# %%
# drop the 'old' index

sat_2019.drop(columns = ['index'], inplace = True)

# %%
# remove non-USA states

sat_2018.drop([8], inplace = True)

# %%
#reset the index after removing non-USA states

sat_2018.reset_index(inplace = True)

# %%
# drop the 'old' index

sat_2018.drop(columns = 'index', inplace = True)

# %%
#sort between Ohio and Oklahoma
#use sort to rearrange alphabetical order

sat_2018.sort_values('State', inplace = True)

# %%
# remove non-USA states

sat_2017.drop([8], inplace = True)

# %%
#reset the index after removing non-USA states

sat_2017.reset_index(inplace = True)

# %%
# drop the 'old' index

sat_2017.drop(columns = 'index', inplace = True)

# %% [markdown]
# **Additional data - historical income in the USA**

# %% [markdown]
# Source - https://www.census.gov/data/tables/time-series/demo/income-poverty/historical-income-households.html

# %%
US_income = pd.read_csv('USA_income.csv')

US_income.head()
# Out:
#            State           2019      Unnamed: 2           2018  \
# 0            NaN  Median income  Standard error  Median income
# 1  United States         68,703             550         63,179
# 2        Alabama         56,200           2,512         49,936
# 3         Alaska         78,394           6,685         68,734
# 4        Arizona         70,674           3,391         62,283
#
#        Unnamed: 4      2017 (40)      Unnamed: 6           2017  \
# 0  Standard error  Median income  Standard error  Median income
# 1             420         61,136             322         61,372
# 2           2,423         50,865           1,094         51,113
# 3           3,390         77,987           3,718         72,231
# 4           2,291         59,700           2,689         61,125
#
#        Unnamed: 8           2016  ...           1988     Unnamed: 68  \
# 0  Standard error  Median income  ...  Median income  Standard error
# ...

# %%
US_income.drop(['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', '2017 (40)'], axis=1, inplace = True)

# %%
US_income.dropna(axis=0, inplace = True)

# %%
#remove district of columbia and United States

US_income.drop([1, 10], inplace = True)

# %%
US_income.reset_index(inplace = True)

# %%
# drop the 'old' index

US_income.drop(columns = 'index', inplace = True)

# %%
US_income['2019'] = US_income['2019'].map(obj_convert)
US_income['2018'] = US_income['2018'].map(obj_convert)
US_income['2017'] = US_income['2017'].map(obj_convert)

# %%
US_income.head()
# Out:
#         State     2019     2018     2017 Unnamed: 8    2016 Unnamed: 10  \
# 0     Alabama  56200.0  49936.0  51113.0        845  47,221       2,301
# 1      Alaska  78394.0  68734.0  72231.0      2,719  75,723       4,086
# 2     Arizona  70674.0  62283.0  61125.0      2,642  57,100       1,971
# 3    Arkansas  54539.0  49781.0  48829.0      2,642  45,907       2,165
# 4  California  78105.0  70489.0  69759.0      1,452  66,637       1,075
#
#      2015 Unnamed: 12    2014  ...    1988 Unnamed: 68 1987 (21) Unnamed: 70  \
# 0  44,509       3,419  42,278  ...  19,948         912    19,734       1,147
# 1  75,112       3,485  67,629  ...  33,103       1,183    33,233       1,497
# 2  52,248       2,008  49,254  ...  26,435         843    26,749         892
# 3  42,798       1,572  44,922  ...  20,172         706    18,827       1,008
# 4  63,636       1,711  60,487  ...  30,287         634    30,146         538
#
#      1986 Unnamed: 72 1985 (20) Unnamed: 74 1984 (19) Unnamed: 76
# ...

# %%
US_income_17_18_19 = US_income[['State', '2019', '2018', '2017']]

# %%
US_income_17_18_19.head()
# Out:
#         State     2019     2018     2017
# 0     Alabama  56200.0  49936.0  51113.0
# 1      Alaska  78394.0  68734.0  72231.0
# 2     Arizona  70674.0  62283.0  61125.0
# 3    Arkansas  54539.0  49781.0  48829.0
# 4  California  78105.0  70489.0  69759.0

# %% [markdown]
# **5) Display the data types of each feature.**

# %%
#datatype checked in no. 2

# %% [markdown]
# **6) Fix any incorrect data types found in step 5**

# %%
#convert string to float

sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(str_convert)

# %%
#convert string to float

sat_2018['Participation'] = sat_2018['Participation'].map(str_convert)

# %%
#convert string to float

sat_2017['Participation'] = sat_2017['Participation'].map(str_convert)

# %% [markdown]
# **7) Rename Columns**

# %% [markdown]
# **SATS**

# %%
sat_2019.rename(columns = {
    'State': 'state', 
    'Participation Rate': 'sat_participation_19',
    'EBRW': 'sat_read_write_scores_19',
    'Math': 'sat_math_scores_19',
    'Total': 'sat_total_scores_19'
}, inplace = True)

# %%
sat_2018.rename(columns = 
                {'State': 'state',
                 'Participation': 'sat_participation_18',
                 'Evidence-Based Reading and Writing': 'sat_read_write_scores_18',
                 'Math': 'sat_math_scores_18',
                 'Total': 'sat_total_scores_18'},
                 inplace = True)

# %%
sat_2017.rename(columns = {
    'State': 'state',
    'Participation': 'sat_participation_17',
    'Evidence-Based Reading and Writing': 'sat_read_write_scores_17',
    'Math': 'sat_math_scores_17',
    'Total': 'sat_total_scores_17'
}, inplace = True)

# %% [markdown]
# **8) Drop unnecessary rows (if needed).**

# %%
#rows dropped in step 4, i.e. removing non-USA states

# %% [markdown]
# **9) Merge dataframes that can be merged.**

# %%
# combine 2017 and 2018 data first

combi_sat_2017_2018 = pd.merge(sat_2017, sat_2018, on='state')

# %%
combi_sat_2017_2018.head()
# Out:
#         state  sat_participation_17  sat_read_write_scores_17  \
# 0     Alabama                  0.05                       593
# 1      Alaska                  0.38                       547
# 2     Arizona                  0.30                       563
# 3    Arkansas                  0.03                       614
# 4  California                  0.53                       531
#
#    sat_math_scores_17  sat_total_scores_17  sat_participation_18  \
# 0                 572                 1165                  0.06
# 1                 533                 1080                  0.43
# 2                 553                 1116                  0.29
# 3                 594                 1208                  0.05
# 4                 524                 1055                  0.60
#
#    sat_read_write_scores_18  sat_math_scores_18  sat_total_scores_18
# 0                       595                 571                 1166
# ...

# %%
#after that, combine 2019 data to the combined 2017-2018 data

combi_sat_2017_2018_2019 = pd.merge(combi_sat_2017_2018, sat_2019, on='state')

# %%
combi_sat_2017_2018_2019.head()
# Out:
#         state  sat_participation_17  sat_read_write_scores_17  \
# 0     Alabama                  0.05                       593
# 1      Alaska                  0.38                       547
# 2     Arizona                  0.30                       563
# 3    Arkansas                  0.03                       614
# 4  California                  0.53                       531
#
#    sat_math_scores_17  sat_total_scores_17  sat_participation_18  \
# 0                 572                 1165                  0.06
# 1                 533                 1080                  0.43
# 2                 553                 1116                  0.29
# 3                 594                 1208                  0.05
# 4                 524                 1055                  0.60
#
#    sat_read_write_scores_18  sat_math_scores_18  sat_total_scores_18  \
# 0                       595                 571                 1166
# ...

# %% [markdown]
# Saving the clean-up files as new csv files

# %%
sat_2017.to_csv(r'C:\Users\Leemei\Data Science\GA\projects\project_1\code\sat_2017(cleanup).csv', index = False)
sat_2018.to_csv(r'C:\Users\Leemei\Data Science\GA\projects\project_1\code\sat_2018(cleanup).csv', index = False)
sat_2019.to_csv(r'C:\Users\Leemei\Data Science\GA\projects\project_1\code\sat_2019(cleanup).csv', index = False)
US_income_17_18_19.to_csv(r'C:\Users\Leemei\Data Science\GA\projects\project_1\code\USA_income(cleanup).csv', index = False)

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|string|SAT|The states in the USA|
# |sat_participation|float|SAT|The percentage expressed as a float on the number of students enrolled in schools|
# |sat_read_write_scores|float|SAT|The average reading and writing score in a maximum score of 800|
# |sat_math_scores|float|SAT|The average math score in a maximum score of 800|
# |sat_total_scores|float|SAT|The combined score of sat_read_and_write and sat_math|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# **1) Summary Statistics.**

# %%
summary_sat = combi_sat_2017_2018_2019.describe()

# %%
summary_sat.T
# Out:
#                           count       mean        std     min        25%  \
# sat_participation_17       50.0     0.3860   0.345602    0.02     0.0400
# sat_read_write_scores_17   50.0   570.8600  44.385146  503.00   535.2500
# sat_math_scores_17         50.0   549.2200  84.998269   52.00   523.2500
# sat_total_scores_17        50.0  1129.6200  89.913085  996.00  1057.0000
# sat_participation_18       50.0     0.4482   0.370976    0.02     0.0425
# sat_read_write_scores_18   50.0   565.0200  47.010416  480.00   535.0000
# sat_math_scores_18         50.0   557.7600  46.987432  486.00   524.2500
# sat_total_scores_18        50.0  1122.8800  92.845634  998.00  1062.2500
# sat_participation_19       50.0     0.4816   0.386002    0.02     0.0525
# sat_read_write_scores_19   50.0   562.1200  45.742688  483.00   529.5000
# sat_math_scores_19         50.0   553.6400  50.753409  460.00   516.7500
# sat_total_scores_19        50.0  1115.8400  96.142403  943.00  1049.0000
#
# ...

# %% [markdown]
# **2. Using a dictionary comprehension to apply the standard deviation function created in part 1 to each numeric column in the dataframe**

# %%
df = combi_sat_2017_2018_2019[combi_sat_2017_2018_2019.columns[1:]]

# %%
sd = {k: std_dev(df[k]) for k in df.columns }

# %%
sd
# Out:
# {'sat_participation_17': 5.670361187790422,
#  'sat_read_write_scores_17': 565.3653063285719,
#  'sat_math_scores_17': 543.7255175178005,
#  'sat_total_scores_17': 1124.1226687510575,
#  'sat_participation_18': 5.614328387260581,
#  'sat_read_write_scores_18': 559.5253617129433,
#  'sat_math_scores_18': 552.2654321972361,
#  'sat_total_scores_18': 1117.382684848839,
#  'sat_participation_19': 5.584293917766148,
#  'sat_read_write_scores_19': 556.6253896472923,
#  'sat_math_scores_19': 548.1454730270059,
#  'sat_total_scores_19': 1110.342701871814}

# %% [markdown]
# **3) Investigate trends in the data.**

# %% [markdown]
# **Top 10 and bottom 10 for 2019**

# %%
# Top 10 states with the highest participation in SAT 

Top_10_sat_2019_participation = sat_2019.sort_values('sat_participation_19', ascending = False).head(10)

Top_10_sat_2019_participation
# Out:
#             state  sat_participation_19  sat_read_write_scores_19  \
# 21       Michigan                  1.00                       507
# 5        Colorado                  1.00                       518
# 6     Connecticut                  1.00                       529
# 7        Delaware                  1.00                       499
# 8         Florida                  1.00                       516
# 11          Idaho                  1.00                       505
# 12       Illinois                  1.00                       509
# 38   Rhode Island                  1.00                       503
# 47  West Virginia                  0.99                       483
# 18          Maine                  0.99                       512
#
#     sat_math_scores_19  sat_total_scores_19
# 21                 496                 1003
# 5                  506                 1024
# 6                  516                 1046
# 7                  486                  985
# ...

# %% [markdown]
# Comment -
# 1. The states listed above are the states with the highest participation in SAT in 2019
# 2. SAT is mandatory at these states

# %%
# The 10 states with the lowest participation rate

Bottom_10_sat_2019 = sat_2019.sort_values('sat_participation_19', ascending = False).tail(10)

Bottom_10_sat_2019
# Out:
#            state  sat_participation_19  sat_read_write_scores_19  \
# 43          Utah                  0.04                       614
# 16      Kentucky                  0.04                       620
# 15        Kansas                  0.04                       618
# 26      Nebraska                  0.03                       628
# 23   Mississippi                  0.03                       628
# 40  South Dakota                  0.03                       633
# 14          Iowa                  0.03                       622
# 48     Wisconsin                  0.03                       635
# 49       Wyoming                  0.03                       623
# 33  North Dakota                  0.02                       627
#
#     sat_math_scores_19  sat_total_scores_19
# 43                 615                 1230
# 16                 612                 1232
# 15                 623                 1241
# 26                 631                 1260
# ...

# %% [markdown]
# Comment - The states listed above are the states with the lowest participation in SAT in 2019

# %%
# Top 10 states with the highest scores in SAT

Top_10_sat_2019_scores = sat_2019.sort_values('sat_total_scores_19', ascending = False).head(10)

Top_10_sat_2019_scores
# Out:
#            state  sat_participation_19  sat_read_write_scores_19  \
# 22     Minnesota                  0.04                       636
# 48     Wisconsin                  0.03                       635
# 40  South Dakota                  0.03                       633
# 33  North Dakota                  0.02                       627
# 26      Nebraska                  0.03                       628
# 14          Iowa                  0.03                       622
# 15        Kansas                  0.04                       618
# 49       Wyoming                  0.03                       623
# 23   Mississippi                  0.03                       628
# 24      Missouri                  0.04                       622
#
#     sat_math_scores_19  sat_total_scores_19
# 22                 648                 1284
# 48                 648                 1283
# 40                 635                 1268
# 33                 636                 1263
# ...

# %% [markdown]
# Comment - The states listed above are the states with the highest scores in SAT in 2019

# %%
# Bottom 10 states with the lowest scores in SAT

Bottom_10_sat_2019_scores = sat_2019.sort_values('sat_total_scores_19', ascending = False).tail(10)

Bottom_10_sat_2019_scores
# Out:
#             state  sat_participation_19  sat_read_write_scores_19  \
# 42          Texas                  0.68                       515
# 18          Maine                  0.99                       512
# 12       Illinois                  1.00                       509
# 21       Michigan                  1.00                       507
# 8         Florida                  1.00                       516
# 38   Rhode Island                  1.00                       503
# 11          Idaho                  1.00                       505
# 7        Delaware                  1.00                       499
# 35       Oklahoma                  0.22                       490
# 47  West Virginia                  0.99                       483
#
#     sat_math_scores_19  sat_total_scores_19
# 42                 507                 1022
# 18                 502                 1013
# 12                 504                 1013
# 21                 496                 1003
# ...

# %% [markdown]
# Comment - The states listed above are the states with the lowest scores in SAT in 2019

# %% [markdown]
# **Top 10 and bottom 10 for 2018**

# %%
# Top 10 states with the highest participation in SAT

Top_10_sat_2018_participation = sat_2018.sort_values('sat_participation_18', ascending = False).head(10)

Top_10_sat_2018_participation

# Majority of the states are the states whereby SAT is mandatory
# Out:
#             state  sat_participation_18  sat_read_write_scores_18  \
# 5        Colorado                  1.00                       519
# 6     Connecticut                  1.00                       535
# 7        Delaware                  1.00                       505
# 21       Michigan                  1.00                       511
# 11          Idaho                  1.00                       508
# 18          Maine                  0.99                       512
# 12       Illinois                  0.99                       513
# 38   Rhode Island                  0.97                       513
# 28  New Hampshire                  0.96                       535
# 29     New Jersey                  0.82                       547
#
#     sat_math_scores_18  sat_total_scores_18
# 5                  506                 1025
# 6                  519                 1053
# 7                  492                  998
# 21                 499                 1011
# ...

# %% [markdown]
# Comment -
# 1. The states listed above are the states with the highest participation in SAT in 2018
# 2. SAT is mandatory at majority of these states

# %%
# Bottom 10 states with the lowest participation in SAT

Bottom_10_sat_2018_participation = sat_2018.sort_values('sat_participation_18', ascending = False).tail(10)

Bottom_10_sat_2018_participation
# Out:
#            state  sat_participation_18  sat_read_write_scores_18  \
# 43          Utah                  0.04                       480
# 16      Kentucky                  0.04                       630
# 15        Kansas                  0.04                       633
# 26      Nebraska                  0.03                       629
# 23   Mississippi                  0.03                       630
# 40  South Dakota                  0.03                       622
# 14          Iowa                  0.03                       634
# 48     Wisconsin                  0.03                       641
# 49       Wyoming                  0.03                       633
# 33  North Dakota                  0.02                       640
#
#     sat_math_scores_18  sat_total_scores_18
# 43                 530                 1010
# 16                 618                 1248
# 15                 631                 1265
# 26                 623                 1252
# ...

# %%
Comment - The states listed above are the states with the lowest participation in SAT in 2018

# %%
# Top 10 states with the highest scores in SAT --> 

Top_10_sat_2018_scores = sat_2018.sort_values('sat_total_scores_18', ascending = False).head(10)

Top_10_sat_2018_scores
# Out:
#            state  sat_participation_18  sat_read_write_scores_18  \
# 22     Minnesota                  0.04                       643
# 48     Wisconsin                  0.03                       641
# 33  North Dakota                  0.02                       640
# 14          Iowa                  0.03                       634
# 15        Kansas                  0.04                       633
# 24      Missouri                  0.04                       633
# 49       Wyoming                  0.03                       633
# 26      Nebraska                  0.03                       629
# 16      Kentucky                  0.04                       630
# 40  South Dakota                  0.03                       622
#
#     sat_math_scores_18  sat_total_scores_18
# 22                 655                 1298
# 48                 653                 1294
# 33                 643                 1283
# 14                 631                 1265
# ...

# %% [markdown]
# Comment - The states listed above are the states with the highest scores in SAT in 2018

# %%
# Bottom 10 states with the lowest scores in SAT --> 

Bottom_10_sat_2018_scores = sat_2018.sort_values('sat_total_scores_18', ascending = False).tail(10)

Bottom_10_sat_2018_scores
# Out:
#             state  sat_participation_18  sat_read_write_scores_18  \
# 5        Colorado                  1.00                       519
# 12       Illinois                  0.99                       513
# 38   Rhode Island                  0.97                       513
# 18          Maine                  0.99                       512
# 21       Michigan                  1.00                       511
# 43           Utah                  0.04                       480
# 10         Hawaii                  0.56                       480
# 11          Idaho                  1.00                       508
# 47  West Virginia                  0.28                       513
# 7        Delaware                  1.00                       505
#
#     sat_math_scores_18  sat_total_scores_18
# 5                  506                 1025
# 12                 506                 1019
# 38                 505                 1018
# 18                 501                 1013
# ...

# %% [markdown]
# Comment - The states listed above are the states with the lowest scores in SAT in 2018

# %% [markdown]
# **Top 10 and bottom 10 for 2017**

# %%
# Top 10 states with the highest scores in SAT --> 

Top_10_sat_2017_scores = sat_2017.sort_values('sat_total_scores_17', ascending = False).head(10)

Top_10_sat_2017_scores
# Out:
#            state  sat_participation_17  sat_read_write_scores_17  \
# 22     Minnesota                  0.03                       644
# 48     Wisconsin                  0.03                       642
# 14          Iowa                  0.02                       641
# 24      Missouri                  0.03                       640
# 15        Kansas                  0.04                       632
# 33  North Dakota                  0.02                       635
# 26      Nebraska                  0.03                       629
# 16      Kentucky                  0.04                       631
# 23   Mississippi                  0.02                       634
# 43          Utah                  0.03                       624
#
#     sat_math_scores_17  sat_total_scores_17
# 22                 651                 1295
# 48                 649                 1291
# 14                 635                 1275
# 24                 631                 1271
# ...

# %% [markdown]
# Comment - The states listed above are the states with the highest scores in SAT in 2017

# %%
# Bottom 10 states with the lowest scores in SAT --> 

Bottom_10_sat_2017_scores = sat_2017.sort_values('sat_total_scores_17', ascending = False).tail(10)

Bottom_10_sat_2017_scores
# Out:
#             state  sat_participation_17  sat_read_write_scores_17  \
# 28  New Hampshire                  0.96                       532
# 9         Georgia                  0.61                       535
# 35       Oklahoma                  0.07                       530
# 6     Connecticut                  1.00                       530
# 42          Texas                  0.62                       513
# 8         Florida                  0.83                       520
# 18          Maine                  0.95                       513
# 11          Idaho                  0.93                       513
# 21       Michigan                  1.00                       509
# 7        Delaware                  1.00                       503
#
#     sat_math_scores_17  sat_total_scores_17
# 28                 520                 1052
# 9                  515                 1050
# 35                 517                 1047
# 6                  512                 1041
# ...

# %% [markdown]
# Comment - The states listed above are the states with the lowest scores in SAT in 2017

# %% [markdown]
# **States with top scorers consistently year on year from 2017-2019**

# %%
# states which have been consistent as top 10 scorer for 2017-2018

Top_scorers_17_18 = pd.merge(Top_10_sat_2017_scores, Top_10_sat_2018_scores, on = 'state', how = 'inner')
Top_scorers_17_18
# Out:
#           state  sat_participation_17  sat_read_write_scores_17  \
# 0     Minnesota                  0.03                       644
# 1     Wisconsin                  0.03                       642
# 2          Iowa                  0.02                       641
# 3      Missouri                  0.03                       640
# 4        Kansas                  0.04                       632
# 5  North Dakota                  0.02                       635
# 6      Nebraska                  0.03                       629
# 7      Kentucky                  0.04                       631
#
#    sat_math_scores_17  sat_total_scores_17  sat_participation_18  \
# 0                 651                 1295                  0.04
# 1                 649                 1291                  0.03
# 2                 635                 1275                  0.03
# 3                 631                 1271                  0.04
# ...

# %%
#states which have been consistent as top 10 scorer for 2017-2019

Top_scorers_17_18_19 = pd.merge(Top_scorers_17_18, Top_10_sat_2019_scores, on = 'state', how = 'inner')
Top_scorers_17_18_19
# Out:
#           state  sat_participation_17  sat_read_write_scores_17  \
# 0     Minnesota                  0.03                       644
# 1     Wisconsin                  0.03                       642
# 2          Iowa                  0.02                       641
# 3      Missouri                  0.03                       640
# 4        Kansas                  0.04                       632
# 5  North Dakota                  0.02                       635
# 6      Nebraska                  0.03                       629
#
#    sat_math_scores_17  sat_total_scores_17  sat_participation_18  \
# 0                 651                 1295                  0.04
# 1                 649                 1291                  0.03
# 2                 635                 1275                  0.03
# 3                 631                 1271                  0.04
# 4                 628                 1260                  0.04
# ...

# %% [markdown]
# **Do any states show have >50% participation on both tests each year?**

# %%
Exceed_50_sat_19 = sat_2019[sat_2019.sat_participation_19 > 0.5]

Exceed_50_sat_18 = sat_2018[sat_2018.sat_participation_18 > 0.5]

Exceed_50_sat_17 = sat_2017[sat_2017.sat_participation_17 > 0.5]

Exceed_50_sat_17_18 = pd.merge(Exceed_50_sat_17, Exceed_50_sat_18, on = 'state', how = 'inner')

Exceed_50_sat_17_18_19 = pd.merge(Exceed_50_sat_17_18, Exceed_50_sat_19, on = 'state', how = 'inner')

Exceed_50_sat_17_18_19[['state','sat_participation_17','sat_participation_18', 'sat_participation_19']]

# This is the list of states which maintained participation rate above 50% year on year from 2017-2019
# Out:
#             state  sat_participation_17  sat_participation_18  \
# 0      California                  0.53                  0.60
# 1     Connecticut                  1.00                  1.00
# 2        Delaware                  1.00                  1.00
# 3         Florida                  0.83                  0.56
# 4         Georgia                  0.61                  0.70
# 5          Hawaii                  0.55                  0.56
# 6           Idaho                  0.93                  1.00
# 7         Indiana                  0.63                  0.63
# 8           Maine                  0.95                  0.99
# 9        Maryland                  0.69                  0.76
# 10  Massachusetts                  0.76                  0.80
# 11       Michigan                  1.00                  1.00
# 12  New Hampshire                  0.96                  0.96
# 13     New Jersey                  0.70                  0.82
# ...

# %%
#These are the states with the highest participation in either of 2017-2019
#We can observe a steep rise of participation in Colorado,Illinois and West Virginia in 2018 (from 2017) as SAT was made mandatory during that time 

Top_participants = combi_sat_2017_2018_2019[(combi_sat_2017_2018_2019['sat_participation_17'] > 0.95)| (combi_sat_2017_2018_2019['sat_participation_18'] > 0.95) | (combi_sat_2017_2018_2019['sat_participation_19'] > 0.95 ) ]

Top_participating_states = Top_participants[['state', 'sat_participation_17','sat_participation_18', 'sat_participation_19']]

Top_participating_states
# Out:
#             state  sat_participation_17  sat_participation_18  \
# 5        Colorado                  0.11                  1.00
# 6     Connecticut                  1.00                  1.00
# 7        Delaware                  1.00                  1.00
# 8         Florida                  0.83                  0.56
# 11          Idaho                  0.93                  1.00
# 12       Illinois                  0.09                  0.99
# 18          Maine                  0.95                  0.99
# 21       Michigan                  1.00                  1.00
# 28  New Hampshire                  0.96                  0.96
# 38   Rhode Island                  0.71                  0.97
# 47  West Virginia                  0.14                  0.28
#
#     sat_participation_19
# 5                   1.00
# 6                   1.00
# 7                   1.00
# 8                   1.00
# 11                  1.00
# 12                  1.00
# 18                  0.99
# ...

# %%
#These are the states with the least participation in either of 2017-2019

Least_participants = combi_sat_2017_2018_2019[(combi_sat_2017_2018_2019['sat_participation_17'] < 0.05)| (combi_sat_2017_2018_2019['sat_participation_18'] < 0.05) | (combi_sat_2017_2018_2019['sat_participation_19'] < 0.05 ) ]

Least_participating_states = Least_participants[['state', 'sat_participation_17','sat_participation_18', 'sat_participation_19']]

Least_participating_states
# Out:
#            state  sat_participation_17  sat_participation_18  \
# 3       Arkansas                  0.03                  0.05
# 14          Iowa                  0.02                  0.03
# 15        Kansas                  0.04                  0.04
# 16      Kentucky                  0.04                  0.04
# 17     Louisiana                  0.04                  0.04
# 22     Minnesota                  0.03                  0.04
# 23   Mississippi                  0.02                  0.03
# 24      Missouri                  0.03                  0.04
# 26      Nebraska                  0.03                  0.03
# 33  North Dakota                  0.02                  0.02
# 40  South Dakota                  0.03                  0.03
# 43          Utah                  0.03                  0.04
# 48     Wisconsin                  0.03                  0.03
# 49       Wyoming                  0.03                  0.03
#
#     sat_participation_19
# ...

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*
#
# **For ease of reference, findings have been stated at each individual cell**

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# **Heatmap**

# %%
plt.figure(figsize=(12,12))
sns.heatmap(combi_sat_2017_2018_2019.corr(), annot=True)
plt.title("Heatmap SAT 2017-2019")
# Out:
# Text(0.5, 1.0, 'Heatmap SAT 2017-2019')

# %% [markdown]
# Variables to be used in the subsequent charts

# %%
sat_participation_2017 = sat_2017['sat_participation_17']
sat_participation_2018 = sat_2018['sat_participation_18']
sat_participation_2019 = sat_2019['sat_participation_19']

scores2017 = sat_2017['sat_total_scores_17']
scores2018 = sat_2018['sat_total_scores_18']
scores2019 = sat_2019['sat_total_scores_19']

income2017 = US_income_17_18_19['2017']
income2018 = US_income_17_18_19['2018']
income2019 = US_income_17_18_19['2019']

# %%
participation_mean_17 = round(combi_sat_2017_2018_2019['sat_participation_17'].mean(), 2)
participation_mean_18 = round(combi_sat_2017_2018_2019['sat_participation_18'].mean(), 2)
participation_mean_19 = round(combi_sat_2017_2018_2019['sat_participation_19'].mean(), 2)

# %%
#compound annual growth rate of SAT participation from 2017 - 2019

CAGR = round(((participation_mean_19 / participation_mean_17)**0.5-1)*100, 0)
CAGR
# Out:
# 11.0

# %%
average_scores_17 = round(combi_sat_2017_2018_2019['sat_total_scores_17'].mean(), 0)
average_scores_18 = round(combi_sat_2017_2018_2019['sat_total_scores_18'].mean(), 0)
average_scores_19 = round(combi_sat_2017_2018_2019['sat_total_scores_19'].mean(), 0)

# %% [markdown]
# **Overview of SAT participation rates from 2017-2019**
#
# *Observation - We observe a general increase in SAT participation rates as depicted by the box plot and bar chart and average participation rate each year*

# %%
columns = [sat_participation_2017, sat_participation_2018, sat_participation_2019]

fig, ax = plt.subplots()
ax.boxplot(columns)
plt.xticks([1, 2, 3], ["SAT participation2017", "SAT participation 2018", "SAT participation 2019"], rotation=10)
ax.set_title('Sat participation rate 2017 - 2019, CAGR {}%'.format(CAGR))
plt.show()

# %%
plt.figure(figsize =(16,18))

ax1 = plt.subplot(3,2,1)
ax1.set_title('Sat participation rate 2017 - average, {}'.format(participation_mean_17))
ax1.hist(sat_participation_2017);
plt.ylabel("No. of states")
plt.xlabel("Participation rate")

ax2 = plt.subplot(3,2,2)
ax2.set_title('Sat participation rate 2018 - average, {}'.format(participation_mean_18))
ax2.hist(sat_participation_2018);
plt.ylabel("No. of states")
plt.xlabel("Participation rate")

ax2 = plt.subplot(3,2,3)
ax2.set_title('Sat participation rate 2019 - average, {}'.format(participation_mean_19))
ax2.hist(sat_participation_2019);
plt.ylabel("No. of states")
plt.xlabel("Participation rate")
# Out:
# Text(0.5, 0, 'Participation rate')

# %% [markdown]
# **Relationship between participation rate and scores from 2017-2019**
#
# *Observation - generally we can observe a downward trend between participation rate and scores, which implies that the higher the participation rate, the lower the average total scores tend to be.States with highest participation rate tend to be states which imposed SAT as mandatory, hence the average score reflects performance of all students (both strong and weak students). As for states whereby SAT is not mandatory, there is a high likelihood that only strong students participated, which may explain the tendency for such states to have higher results*

# %%
plt.figure(figsize =(18,16))

ax1 = plt.subplot(3,2,1)
ax1.set_title('Sat participation vs score 2017')
sns.regplot(x= sat_participation_2017, y=scores2017);
plt.ylabel("SAT Scores")
plt.xlabel("Participation")

ax2 = plt.subplot(3,2,2)
ax2.set_title('Sat participation vs score 2018')
sns.regplot(x= sat_participation_2018, y=scores2018);
plt.ylabel("SAT Scores")
plt.xlabel("Participation")

ax2 = plt.subplot(3,2,3)
ax2.set_title('Sat participation vs score 2019')
sns.regplot(x= sat_participation_2019, y=scores2019);
plt.ylabel("SAT Scores")
plt.xlabel("Participation")
# Out:
# Text(0.5, 0, 'Participation')

# %% [markdown]
# **Relationship between income and scores from 2017-2019**
#
# *Observation - generally there is no clear linear trend between income and scores, which implies that scores in SAT were not influenced by the median income of each state. However, this data may not be accurate because less well-to-do students may drop out of SAT and hence, this data may be biased. Further analysis is required to ascertain this.*

# %%
plt.figure(figsize =(18,16))

ax1 = plt.subplot(3,2,1)
ax1.set_title('SAT: income vs score 2017')
sns.regplot(x= income2017, y=scores2017);
plt.ylabel("SAT Scores")
plt.xlabel("Income")

ax2 = plt.subplot(3,2,2)
ax2.set_title('SAT: income vs score 2018')
sns.regplot(x= income2018, y=scores2018);
plt.ylabel("SAT Scores")
plt.xlabel("Income")

ax2 = plt.subplot(3,2,3)
ax2.set_title('SAT: income vs score 2019')
sns.regplot(x= income2019, y=scores2019);
plt.ylabel("SAT Scores")
plt.xlabel("Income")
# Out:
# Text(0.5, 0, 'Income')

# %% [markdown]
# **Comparing average scores from 2017-2019**
#
# *Observation - Overall, we can observe declining trend in average SAT scores year-on-year. This could be explained by the general increase in overall participation by students from various capabilities (not just strong students who participated). We observe that scores tend to be somewhat normally distributed*.

# %%
plt.figure(figsize =(16,19))

ax1 = plt.subplot(3,2,1)
ax1.set_title('Sat 2017 scores - average, {}'.format(average_scores_17))
sns.distplot(scores2017, kde = True);

ax2 = plt.subplot(3,2,2)
ax2.set_title('Sat 2018 scores- average, {}'.format(average_scores_18))
sns.distplot(scores2018, kde = True);

ax2 = plt.subplot(3,2,3)
ax2.set_title('Sat 2019 scores- average, {}'.format(average_scores_19))
sns.distplot(scores2019, kde = True);

# %% [markdown]
# **Comparing range of scores from 2017-2019**
#
# *Observation - Overall, we can observe similar range of average total scores from close to 1,000 to 1,300*.

# %%
columns = [scores2017, scores2018, scores2019]

fig, ax = plt.subplots()
ax.boxplot(columns)
plt.xticks([1, 2, 3], ["SAT scores 2017", "SAT scores 2018", "SAT scores 2019"], rotation=10)
ax.set_title('Sat average scores 2017 - 2019')
plt.show()

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Key takeaways**
#
# 1. The states with the highest participation rate tend to be states which impose SAT as mandatory
# 2. Score wise, we observe that the higher the participation rate, the lower the average total SAT scores. States with highest participation rate tend to be states which imposed SAT as mandatory, hence the average score reflects performance of students of various capabilities (i.e. strong and weaker students). As for states whereby SAT is not mandatory, there is a high likelihood that only strong students participated, which may explain the tendency for these states to have higher average scores
# 3. Generally there is no trend between income and scores, which means that SAT scores were not influenced by the income of each state. However, this data may not be accurate because less well-to-do students may drop out of SAT (more so, in states where SAT is not mandatory) and hence, this data may be biased.
# 3. Overall, there is an improvement in participation rates of SAT from 2017 to 2019 (with a compound annual growth rate of approximately 11%) as certain states made the move to impose SAT as mandatory.
#
# **Recommendations**
#
# Our client should channel its budget in these states:
#
# |Budget|States selected|Basis|Justification|
# |---|---|---|---|
# |Advertising|Colorado, Connecticut, Delaware, Florida, Idaho, Illinois, Maine, Michigan, New Hampshire, Rhode Island, West Virginia|Top participating states 2017-2019 / States where SAT is compulsory|Large and stable market to advertise the client's business. As SAT is made compulsory, there is a chance for relatively high take-up rate and stable enrolment rate in the near term. Data shows that SAT participation grew at a compound annual growth rate of about 11% from 2017-2019|
# |Advertising and scholarship/financial aid|Arkansas, Iowa, Kansas, Kentucky, Louisiana, Minnesota, Mississipi, Missouri, North Dakota, Nebraska, South Dakota, Utah, Wisconsin, Wyoming|Least participating states (also happened to be top scoring states 2017-2019)|These states are states where SAT is not compulsory. Hence, there is a likelihood that only stronger students participated, as depicted by the relatively high average scores compared to states with higher participation rates. Students in these states who are weaker or not financially able may shy away from SAT. Hence, there is a potential untapped market to be explored in these states. Scholarships/financial aid can be channeled to these states to entice more students to participate (and also enhance client's corporate image and boost publicity)|

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
